# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv("C:/Users/chapa/Desktop/ted_main.csv")

# %%
data2 = pd.read_csv("C:/Users/chapa/Desktop/transcripts.csv")

# %%
data1
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
# ...

# %%
data1.columns
# Out:
# Index(['comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'published_date',
#        'ratings', 'related_talks', 'speaker_occupation', 'tags', 'title',
#        'url', 'views'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['transcript', 'url'], dtype='object')

# %%
data1['film_date']
# Out:
# 0       1140825600
# 1       1140825600
# 2       1140739200
# 3       1140912000
# 4       1140566400
#            ...
# 2545    1496707200
# 2546    1492992000
# 2547    1492992000
# 2548    1499472000
# 2549    1492992000
# Name: film_date, Length: 2550, dtype: int64

# %%
data1['film_date'] = pd.to_datetime(data1['film_date'], unit='s')

data1['year'] = data1['film_date'].dt.year
data1['month'] = data1['film_date'].dt.month
data1['day_of_month'] = data1['film_date'].dt.day
data1['day_of_week'] = data1['film_date'].dt.dayofweek  # Monday=0, Sunday=6
data1['hour'] = data1['film_date'].dt.hour
data1['minute'] = data1['film_date'].dt.minute
data1['second'] = data1['film_date'].dt.second

print(data1)
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
# ...

# %%
data1.rename(columns={
    'year': 'film_date.year',
    'month': 'film_date.month',
    'day_of_month': 'film_date.day_of_month',
    'day_of_week': 'film_date.day_of_week',
    'hour': 'film_date.hour',
    'minute': 'film_date.minute',
    'second': 'film_date.second'
}, inplace=True)

# %%
data1
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
# ...

# %%
data1.columns
# Out:
# Index(['comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'published_date',
#        'ratings', 'related_talks', 'speaker_occupation', 'tags', 'title',
#        'url', 'views', 'film_date.year', 'film_date.month',
#        'film_date.day_of_month', 'film_date.day_of_week', 'film_date.hour',
#        'film_date.minute', 'film_date.second'],
#       dtype='object')

# %%
data1['published_date'] = pd.to_datetime(data1['published_date'], unit='s')
data1['year'] = data1['published_date'].dt.year
data1['month'] = data1['published_date'].dt.month
data1['day_of_month'] = data1['published_date'].dt.day
data1['day_of_week'] = data1['published_date'].dt.dayofweek  # Monday=0, Sunday=6
data1['hour'] = data1['published_date'].dt.hour
data1['minute'] = data1['published_date'].dt.minute
data1['second'] = data1['published_date'].dt.second

# %%
data1.rename(columns={
    'year': 'published_date.year',
    'month': 'published_date.month',
    'day_of_month': 'published_date.day_of_month',
    'day_of_week': 'published_date.day_of_week',
    'hour': 'published_date.hour',
    'minute': 'published_date.minute',
    'second': 'published_date.second'
}, inplace=True)

# %%
data1
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
# ...

# %%
data1.url
# Out:
# 0       https://www.ted.com/talks/ken_robinson_says_sc...
# 1       https://www.ted.com/talks/al_gore_on_averting_...
# 2       https://www.ted.com/talks/david_pogue_says_sim...
# 3       https://www.ted.com/talks/majora_carter_s_tale...
# 4       https://www.ted.com/talks/hans_rosling_shows_t...
#                               ...
# 2545    https://www.ted.com/talks/duarte_geraldino_wha...
# 2546    https://www.ted.com/talks/armando_azua_bustos_...
# 2547    https://www.ted.com/talks/radhika_nagpal_what_...
# 2548    https://www.ted.com/talks/theo_e_j_wilson_a_bl...
# 2549    https://www.ted.com/talks/karoliina_korppoo_ho...
# Name: url, Length: 2550, dtype: object

# %%
data2
# Out:
#                                              transcript  \
# 0     Good morning. How are you?(Laughter)It's been ...
# 1     Thank you so much, Chris. And it's truly a gre...
# 2     (Music: "The Sound of Silence," Simon & Garfun...
# 3     If you're here today — and I'm very happy that...
# 4     About 10 years ago, I took on the task to teac...
# ...                                                 ...
# 2462  So, Ma was trying to explain something to me a...
# 2463  This is a picture of a sunset on Mars taken by...
# 2464  In my early days as a graduate student, I went...
# 2465  I took a cell phone and accidentally made myse...
# 2466  We humans are becoming an urban species, so ci...
#
#                                                     url
# 0     https://www.ted.com/talks/ken_robinson_says_sc...
# 1     https://www.ted.com/talks/al_gore_on_averting_...
# 2     https://www.ted.com/talks/david_pogue_says_sim...
# 3     https://www.ted.com/talks/majora_carter_s_tale...
# ...

# %%
merged_data = pd.merge(data1, data2[['url', 'transcript']], on='url', how='outer')

# %%
merged_data
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2548        17  Between 2008 and 2016, the United States depor...       476
# 2549         6  How can you study Mars without a spaceship? He...       290
# 2550        10  Science fiction visions of the future show us ...       651
# 2551        32  In an unmissable talk about race and politics ...      1100
# 2552         8  With more than half of the world population li...       519
#
# ...

# %%
merged_data[1100:1120]
# Out:
#       comments                                        description  duration  \
# 1100       166  For a full year, AJ Jacobs followed every piec...       522
# 1101       295  Within this generation, an extra 30 years have...       680
# 1102       270  Paddy Ashdown believes we are living in a mome...      1109
# 1103       161  Sebastian Wernicke thinks every TED Talk can b...       454
# 1104        70  We don't just need better laws -- we need bett...       632
# 1105        41  How do you measure a nebula? With a brain scan...       581
# 1106       211  Like all of us, economist Tyler Cowen loves a ...       957
# 1107       170  In 2011 three young women swept the top prizes...       976
# 1108        57  In politics, it seems counterintuitive to enga...       898
# 1109       161  We have no ways to directly observe molecules ...       548
# 1110        45  Inspired by Aung San Suu Kyi's call to action,...       330
# ...

# %%
duplicate_urls_data1 = data1[data1.duplicated(subset='url')]
duplicate_urls_data2 = data2[data2.duplicated(subset='url')]

# %%
duplicate_urls_data2
# Out:
#                                              transcript  \
# 1114  I have a question for you: Are you religious? ...
# 1115  The recent debate over copyright laws like SOP...
# 1116  I'm going to tell you a little bit about my TE...
#
#                                                     url
# 1114  https://www.ted.com/talks/jonathan_haidt_human...
# 1115  https://www.ted.com/talks/rob_reid_the_8_billi...
# 1116  https://www.ted.com/talks/brene_brown_listenin...

# %%
duplicate_urls_merged = merged_data[merged_data.duplicated(subset='url')]

# %%
duplicate_urls_merged
# Out:
#       comments                                        description  duration  \
# 1176       497  Psychologist Jonathan Haidt asks a simple, but...      1096
# 1178       241  Comic author Rob Reid unveils Copyright Math (...       311
# 1180       707  Shame is an unspoken epidemic, the secret behi...      1238
#
#         event  film_date  languages    main_speaker  \
# 1176  TED2012 2012-02-29         31  Jonathan Haidt
# 1178  TED2012 2012-03-01         44        Rob Reid
# 1180  TED2012 2012-03-02         38     Brené Brown
#
#                                                    name  num_speaker  \
# 1176  Jonathan Haidt: Religion, evolution, and the e...            1
# 1178                      Rob Reid: The $8 billion iPod            1
# 1180                    Brené Brown: Listening to shame            1
#
#           published_date  ... film_date.minute film_date.second  \
# 1176 2012-03-14 15:04:35  ...                0                0
# ...

# %%
merged_data.drop_duplicates(inplace =True)

# %%
merged_data.columns
# Out:
# Index(['comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'published_date',
#        'ratings', 'related_talks', 'speaker_occupation', 'tags', 'title',
#        'url', 'views', 'film_date.year', 'film_date.month',
#        'film_date.day_of_month', 'film_date.day_of_week', 'film_date.hour',
#        'film_date.minute', 'film_date.second', 'published_date.year',
#        'published_date.month', 'published_date.day_of_month',
#        'published_date.day_of_week', 'published_date.hour',
#        'published_date.minute', 'published_date.second', 'transcript'],
#       dtype='object')

# %%
merged_data.to_csv("TED_data.csv")

# %%
merged_data.dtypes
# Out:
# comments                                int64
# description                            object
# duration                                int64
# event                                  object
# film_date                      datetime64[ns]
# languages                               int64
# main_speaker                           object
# name                                   object
# num_speaker                             int64
# published_date                 datetime64[ns]
# ratings                                object
# related_talks                          object
# speaker_occupation                     object
# tags                                   object
# title                                  object
# url                                    object
# views                                   int64
# film_date.year                          int64
# film_date.month                         int64
# film_date.day_of_month                  int64
# ...

# %%
merged_data
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2548        17  Between 2008 and 2016, the United States depor...       476
# 2549         6  How can you study Mars without a spaceship? He...       290
# 2550        10  Science fiction visions of the future show us ...       651
# 2551        32  In an unmissable talk about race and politics ...      1100
# 2552         8  With more than half of the world population li...       519
#
# ...
